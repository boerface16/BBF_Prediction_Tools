# %% [markdown]
# # Phase 6: Model Training
# XGBoost/LightGBM with Optuna tuning and SHAP analysis.

# %%
import sys
sys.path.insert(0, '..')

from src.model_trainer import train_pipeline
from src.data_builder import load_config

cfg = load_config()

batter_model, batter_meta, batter_test, batter_shifted = train_pipeline('batter', cfg)
pitcher_model, pitcher_meta, pitcher_test, pitcher_shifted = train_pipeline('pitcher', cfg)
# Out:
# ==================================================
# BATTER MODEL
# ==================================================
# Features: 39
# Total samples: 2695
# Train: 2152, Val: 278, Test: 265
#   COVID feature-year rows downweighted: 271
#
# Baseline models:
#   XGBoost:  MAE=76.6, Spearman=0.579
#   LightGBM: MAE=76.2, Spearman=0.556
#   Winner: xgboost
#
# Optuna tuning (50 trials each)...
#   XGBoost tuned — MAE: 73.6, Spearman: 0.595
#   LightGBM tuned — MAE: 73.9, Spearman: 0.605
#
#   Blend weights — XGBoost: 0.369, LightGBM: 0.631
#
# Test set results:
#   XGBoost  — MAE: 69.3, Spearman: 0.630
#   LightGBM — MAE: 68.7, Spearman: 0.635
#   Ensemble — MAE: 68.6, Spearman: 0.636
#   Train MAE: 52.9, Overfit ratio: 1.30
#
# SHAP analysis (XGBoost component)...
# Top 10 features:
#       feature  shap_importance
#          b_pa        33.778385
#         K_pct        12.309912
# avg_hit_speed         8.470582
#             G         7.360221
#       SB_rate         7.225486
#        est_ba         6.727230
#          wRAA         5.835868
#  sprint_speed         5.709241
#          RE24         5.689672
#      BB_K_pct         5.051812
#   Pareto chart saved: batter_pareto.png (18 features reach 80%)
# ==================================================
# PITCHER MODEL
# ==================================================
# Features: 36
# Total samples: 3185
# Train: 2547, Val: 323, Test: 315
#   COVID feature-year rows downweighted: 328
#
# Baseline models:
#   XGBoost:  MAE=82.0, Spearman=0.468
#   LightGBM: MAE=84.7, Spearman=0.445
#   Winner: xgboost
#
# Optuna tuning (50 trials each)...
#   XGBoost tuned — MAE: 79.4, Spearman: 0.522
#   LightGBM tuned — MAE: 79.9, Spearman: 0.521
#
#   Blend weights — XGBoost: 0.580, LightGBM: 0.420
#
# Test set results:
#   XGBoost  — MAE: 80.9, Spearman: 0.463
#   LightGBM — MAE: 82.7, Spearman: 0.439
#   Ensemble — MAE: 81.4, Spearman: 0.455
#   Train MAE: 57.6, Overfit ratio: 1.41
#
# SHAP analysis (XGBoost component)...
# Top 10 features:
#  feature  shap_importance
#     p_gs        19.028648
# p_ipouts        12.380630
#    K_pct        10.351834
#    p_bfp         9.283864
#     xFIP         9.089806
# K_BB_pct         7.113140
#       K9         6.158111
#     p_gf         5.884092
#        G         5.679143
#       IP         4.873262
#   Pareto chart saved: pitcher_pareto.png (18 features reach 80%)

# %%
# Model performance summary
import json
print('Batter model:')
print(json.dumps(batter_meta['test_metrics'], indent=2))
print('\nPitcher model:')
print(json.dumps(pitcher_meta['test_metrics'], indent=2))
# Out:
# Batter model:
# {
#   "label": "ensemble_test",
#   "MAE": 68.56679602359198,
#   "RMSE": 85.70023171020668,
#   "Spearman": 0.6356048276569892,
#   "p_value": 2.1452759785355113e-31
# }
#
# Pitcher model:
# {
#   "label": "ensemble_test",
#   "MAE": 81.44985720991254,
#   "RMSE": 103.80517333177565,
#   "Spearman": 0.4547389323709555,
#   "p_value": 1.759487277354939e-17
# }
