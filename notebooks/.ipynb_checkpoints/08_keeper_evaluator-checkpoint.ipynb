# %% [markdown]
# # Phase 8: Keeper Evaluator
# Trajectory scores, ML projections, combined keeper recommendations.

# %%
import sys
sys.path.insert(0, '..')

from src.keeper_evaluator import build_keeper_rankings
from src.data_builder import load_config

cfg = load_config()
rankings = build_keeper_rankings(cfg)
# Out:
# Loading data...
# Generating keeper trajectory plots...
# Keeper rankings saved: C:\Users\Jake\Documents\Python\Baseball\fantasy_baseball_tool\outputs\keeper_rankings.csv
# position    first       last  recent_pts  ml_projection  combined_score recommendation  signal_divergence
#        P      Max      Fried       521.0     341.087283        0.853557      AUTO-KEEP              False
#       OF   Heliot      Ramos       302.0     346.329849        0.803121      AUTO-KEEP               True
#        C  Agustín    Ramírez         NaN     298.103531        0.766932      AUTO-KEEP              False
#       2B  Gleyber     Torres       347.0     325.911294        0.757287      AUTO-KEEP               True
#        P     Drew  Rasmussen       372.0     229.053048        0.716612      AUTO-KEEP               True
#        P   Andrés      Muñoz       381.0     281.120299        0.688041      AUTO-KEEP              False
#       OF   Steven       Kwan       387.0     296.460300        0.680248           KEEP              False
#        P    Zebby   Matthews       123.0     265.969692        0.644304           KEEP              False
#       2B Ceddanne    Rafaela       304.0     273.237566        0.641227           KEEP              False
#       3B  Eugenio     Suárez       372.0     273.361409        0.621853           KEEP              False
#       1B     Alec   Burleson       316.0     293.765231        0.619058           KEEP               True
#       OF    Gavin     Sheets       278.0     249.534801        0.609726           KEEP              False
#       OF     Luis Robert Jr.       205.0     251.013248        0.587587           KEEP              False
#        P     Jeff    Hoffman       337.0     242.572415        0.584198           KEEP              False
#        P    David   Peterson       300.0     258.659919        0.574835           KEEP              False
#        P    Tyler    Glasnow       228.0     294.680456        0.533053           KEEP               True
#       SS     Josh      Smith       253.0            NaN        0.511636     BORDERLINE              False
#       OF    Bryan   Reynolds       264.0     255.297499        0.484327     BORDERLINE              False
#        C   Austin      Wells       214.0     223.364994        0.484299     BORDERLINE              False
#        P     Zack    Littell       360.0     207.277261        0.472227     BORDERLINE               True
#        P    Bubba   Chandler         NaN     211.289006        0.347374     BORDERLINE              False
#        P  Michael   McGreevy       163.0     139.410532        0.329675            CUT               True
#        P   Gerrit       Cole       235.0            NaN        0.000000            CUT              False

# %%
# Full keeper rankings
import pandas as pd
kr = pd.read_csv('../outputs/keeper_rankings.csv')
display_cols = ['position','first','last','recent_pts','prior_pts','ml_projection',
                'combined_score','recommendation','signal_divergence']
print(kr[[c for c in display_cols if c in kr.columns]].to_string(index=False))
# Out:
# position    first       last  recent_pts  prior_pts  ml_projection  combined_score recommendation  signal_divergence
#        P      Max      Fried       521.0      395.0     341.087283        0.853557      AUTO-KEEP              False
#       OF   Heliot      Ramos       302.0      257.0     346.329849        0.803121      AUTO-KEEP               True
#        C  Agustín    Ramírez         NaN        NaN     298.103531        0.766932      AUTO-KEEP              False
#       2B  Gleyber     Torres       347.0      298.0     325.911294        0.757287      AUTO-KEEP               True
#        P     Drew  Rasmussen       372.0       73.0     229.053048        0.716612      AUTO-KEEP               True
#        P   Andrés      Muñoz       381.0      281.0     281.120299        0.688041      AUTO-KEEP              False
#       OF   Steven       Kwan       387.0      345.0     296.460300        0.680248           KEEP              False
#        P    Zebby   Matthews       123.0       35.0     265.969692        0.644304           KEEP              False
#       2B Ceddanne    Rafaela       304.0      240.0     273.237566        0.641227           KEEP              False
#       3B  Eugenio     Suárez       372.0      334.0     273.361409        0.621853           KEEP              False
#       1B     Alec   Burleson       316.0      347.0     293.765231        0.619058           KEEP               True
#       OF    Gavin     Sheets       278.0      180.0     249.534801        0.609726           KEEP              False
#       OF     Luis Robert Jr.       205.0      141.0     251.013248        0.587587           KEEP              False
#        P     Jeff    Hoffman       337.0      251.0     242.572415        0.584198           KEEP              False
#        P    David   Peterson       300.0      274.0     258.659919        0.574835           KEEP              False
#        P    Tyler    Glasnow       228.0      372.0     294.680456        0.533053           KEEP               True
#       SS     Josh      Smith       253.0      271.0            NaN        0.511636     BORDERLINE              False
#       OF    Bryan   Reynolds       264.0      350.0     255.297499        0.484327     BORDERLINE              False
#        C   Austin      Wells       214.0      198.0     223.364994        0.484299     BORDERLINE              False
#        P     Zack    Littell       360.0      309.0     207.277261        0.472227     BORDERLINE               True
#        P    Bubba   Chandler         NaN        NaN     211.289006        0.347374     BORDERLINE              False
#        P  Michael   McGreevy       163.0       74.0     139.410532        0.329675            CUT               True
#        P   Gerrit       Cole       235.0      589.0            NaN        0.000000            CUT              False

# %%
# Summary by recommendation
print(kr['recommendation'].value_counts())
# Out:
# recommendation
# KEEP          10
# AUTO-KEEP      6
# BORDERLINE     5
# CUT            2
# Name: count, dtype: int64
