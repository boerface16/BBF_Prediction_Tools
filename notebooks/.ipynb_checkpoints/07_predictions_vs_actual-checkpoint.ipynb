# %% [markdown]
# # Phase 7: Predictions & Draft Rankings
# Test evaluation, 2026 projections, PAR, tiers, risk flags.

# %%
import sys
sys.path.insert(0, '..')

from src.predictor import build_predictions
from src.data_builder import load_config

cfg = load_config()
results = build_predictions(cfg)
# Out:
# ==================================================
# BATTER PREDICTIONS
# ==================================================
#   Generated evaluation plots for 265 test players
#   Saved 348 batter rankings
#   Top 10:
#  overall_rank      last     first primary_pos  projected_pts_2026        PAR  tier       risk_flags
#             1      Soto      Juan          RF          506.819102 296.987554     1
#             2   Ramirez      Jose          3B          485.450809 293.621433     1         age_risk
#             3    Ohtani    Shohei          DH          425.506361 223.197749     2
#             4   Raleigh       Cal           C          387.650964 218.559685     2
#             5     Judge     Aaron          RF          420.661146 210.829599     2 BABIP_regression
#             6 Rodriguez     Julio          CF          411.500313 208.873157     2
#             7    Lindor Francisco          SS          428.677489 202.472768     2         age_risk
#             8  Caminero    Junior          3B          393.717557 201.888181     2
#             9    Garcia    Maikel          3B          393.152457 201.323081     2
#            10    Tucker      Kyle          RF          405.731423 195.899875     2
#
# ==================================================
# PITCHER PREDICTIONS
# ==================================================
#   Generated evaluation plots for 315 test players
#   Saved 475 pitcher rankings
#   Top 10:
#  overall_rank    last   first primary_pos  projected_pts_2026        PAR  tier       risk_flags
#             1 Crochet Garrett           P          480.611863 343.897492     1
#             2 Wheeler    Zack           P          465.224129 328.509759     1
#             3  Skubal   Tarik           P          453.564633 316.850262     1
#             4    Sale   Chris           P          387.616331 250.901961     1
#             5 Gilbert   Logan           P          380.195777 243.481407     1
#             6    Webb   Logan           P          378.426375 241.712005     1 BABIP_regression
#             7   Brown  Hunter           P          372.253137 235.538767     1   ERA_regression
#             8  Greene  Hunter           P          371.727036 235.012666     1   ERA_regression
#             9   Kirby  George           P          363.303741 226.589371     1
#            10     Woo   Bryan           P          360.563814 223.849443     1   ERA_regression

# %%
import pandas as pd
bat_rank = pd.read_csv('../outputs/draft_rankings_batters.csv')
print(f'Batter rankings: {len(bat_rank)}')
print(bat_rank[['overall_rank','last','first','primary_pos','projected_pts_2026','PAR','tier']].head(20).to_string(index=False))
# Out:
# Batter rankings: 348
#  overall_rank      last     first primary_pos  projected_pts_2026        PAR  tier
#             1      Soto      Juan          RF          506.819102 296.987554     1
#             2   Ramirez      Jose          3B          485.450809 293.621433     1
#             3    Ohtani    Shohei          DH          425.506361 223.197749     2
#             4   Raleigh       Cal           C          387.650964 218.559685     2
#             5     Judge     Aaron          RF          420.661146 210.829599     2
#             6 Rodriguez     Julio          CF          411.500313 208.873157     2
#             7    Lindor Francisco          SS          428.677489 202.472768     2
#             8  Caminero    Junior          3B          393.717557 201.888181     2
#             9    Garcia    Maikel          3B          393.152457 201.323081     2
#            10    Tucker      Kyle          RF          405.731423 195.899875     2
#            11     Tatis  Fernando          RF          405.601957 195.770409     2
#            12      Witt     Bobby          SS          421.823272 195.618551     2
#            13  Guerrero  Vladimir          1B          398.784636 192.042924     2
#            14 Schwarber      Kyle          DH          392.859890 190.551278     2
#            15   Perdomo   Geraldo          SS          416.282277 190.077556     2
#            16   Machado     Manny          3B          373.766653 181.937277     2
#            17    Alonso      Pete          1B          385.090185 178.348473     2
#            18      Diaz     Yandy          DH          375.916543 173.607931     2
#            19    Rooker     Brent          DH          375.311252 173.002640     2
#            20     Marte     Ketel          2B          354.037799 170.422477     2

# %%
pit_rank = pd.read_csv('../outputs/draft_rankings_pitchers.csv')
print(f'Pitcher rankings: {len(pit_rank)}')
print(pit_rank[['overall_rank','last','first','projected_pts_2026','PAR','tier']].head(20).to_string(index=False))
# Out:
# Pitcher rankings: 475
#  overall_rank     last      first  projected_pts_2026        PAR  tier
#             1  Crochet    Garrett          480.611863 343.897492     1
#             2  Wheeler       Zack          465.224129 328.509759     1
#             3   Skubal      Tarik          453.564633 316.850262     1
#             4     Sale      Chris          387.616331 250.901961     1
#             5  Gilbert      Logan          380.195777 243.481407     1
#             6     Webb      Logan          378.426375 241.712005     1
#             7    Brown     Hunter          372.253137 235.538767     1
#             8   Greene     Hunter          371.727036 235.012666     1
#             9    Kirby     George          363.303741 226.589371     1
#            10      Woo      Bryan          360.563814 223.849443     1
#            11 Woodruff    Brandon          357.418163 220.703793     1
#            12   deGrom      Jacob          355.506738 218.792367     1
#            13     Ryan        Joe          354.188907 217.474536     1
#            14     Gray      Sonny          353.077479 216.363109     1
#            15  Sanchez Cristopher          352.091174 215.376803     1
#            16 Yamamoto  Yoshinobu          349.422699 212.708329     1
#            17   Ragans       Cole          348.361354 211.646983     1
#            18    Burns      Chase          348.326153 211.611783     1
#            19   Skenes       Paul          346.822457 210.108086     1
#            20  Cabrera     Edward          346.701882 209.987511     1
